# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
np.random.seed(0)

# %%
x,y=make_blobs(n_samples=5000, centers=[[4,4], [-4,4], [4,-4],], cluster_std=0.9)
print(x)
print(y)
# Out:
# [[-4.35656123  2.18794505]
#  [ 3.21625032  5.12895987]
#  [ 3.90443636 -4.53020473]
#  ...
#  [ 4.0644101   3.00444442]
#  [ 4.31188104 -3.27824794]
#  [-4.52055384  4.01944093]]
# [1 0 2 ... 0 2 1]

# %%
plt.scatter(x[:,0], x[:,1], marker=".")

# %%
k_means=KMeans(init="k-means++", n_clusters= 4, n_init=12)

# %%
print(k_means.fit(x))
# Out:
# KMeans(n_clusters=4, n_init=12)

# %%
k_means_labels=k_means.labels_
k_means_labels
# Out:
# array([1, 2, 3, ..., 2, 0, 1], dtype=int32)

# %%
k_means_cluster_centers=k_means.cluster_centers_
k_means_cluster_centers
# Out:
# array([[ 4.38970951, -3.41022139],
#        [-4.03577217,  4.02753515],
#        [ 3.9787146 ,  3.97885305],
#        [ 3.65891466, -4.69592855]])

# %%
fig = plt.figure(figsize=(6, 4))

colors = plt.cm.Spectral(np.linspace(0, 1, len(set(k_means_labels))))

ax = fig.add_subplot(1, 1, 1)

for k, col in zip(range(len([[4,4], [-4,4], [4,-4]])), colors):

    my_members = (k_means_labels == k)
    
    cluster_center = k_means_cluster_centers[k]
    
    ax.plot(x[my_members, 0], x[my_members, 1], 'w', markerfacecolor=col, marker='.')
    
    ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,  markeredgecolor='k', markersize=6)

ax.set_title('KMeans')

ax.set_xticks(())

ax.set_yticks(())

plt.show()
